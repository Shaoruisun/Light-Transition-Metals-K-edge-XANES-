# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sp = {"Mo": [20016], "Ru": [22135], "Rh": [23238], "Y": [17050], "Ni": [8333], "Ti": [4965], "Nb": [18998], "Cr": [5990, 5999], "Co": [7710], "Cu": [8984], "Mn": [6539], "Zr": [18010], "Cd": [26739], "Zn": [9661], "Pd": [24371], "Fe": [7112, 7121], "Tc": [21062], "Ag": [25538], "Sc": [4490], "V": [5465]}


data = pd.read_pickle("./predict_result.pk")
data.head()
# Out:
#                               0         1         2         3         4
# mp-542272-20-Mo-XANES-K -0.000039  0.000203  0.035391  0.041182  0.162080  \
# mp-19704-56-Mo-XANES-K  -0.000016  0.000113  0.000041  0.000672  0.134964
# mp-542188-5-Mo-XANES-K  -0.000040  0.000180  0.000092 -0.000358  0.163374
# mp-542189-11-Mo-XANES-K -0.000041  0.000178  0.000064 -0.000396  0.166447
# mp-542189-7-Mo-XANES-K  -0.000039  0.000179  0.000073 -0.000395  0.164775
#
#                               5         6         7         8         9
# mp-542272-20-Mo-XANES-K  0.181733  0.203244  0.228072  0.252253  0.270838  \
# mp-19704-56-Mo-XANES-K   0.153425  0.164428  0.198794  0.251112  0.285795
# mp-542188-5-Mo-XANES-K   0.180497  0.202712  0.224788  0.254218  0.281457
# mp-542189-11-Mo-XANES-K  0.183484  0.204314  0.225248  0.253323  0.280041
# mp-542189-7-Mo-XANES-K   0.181756  0.204109  0.224981  0.252398  0.278647
#
#                          ...       101       102       103       104
# ...

# %%
data_id = 0


start = int(sp[data.index.to_list()[data_id].split("-")[-3]][0])
x = [i for i in np.arange(start=start, stop=start+55.5, step=0.5)]
y = data.iloc[data_id,:]

plt.figure(figsize=(15,8),dpi=100)
plt.plot(x, y, color='b', label='Pre Data', linewidth=3)
plt.ylim((0,max(y)+0.3))

tickssize=25
plt.xticks(fontsize=tickssize)
plt.yticks(fontsize=tickssize)
labelsize=25
plt.xlabel('Energy/eV',fontsize=labelsize,color='black')
plt.ylabel('Intensity/a.u.',fontsize=labelsize,color='black')
plt.title(label=data.index.to_list()[data_id],fontsize=30,loc='center',color='black')
plt.rcParams.update({'font.size':25})
plt.legend()
plt.show()
